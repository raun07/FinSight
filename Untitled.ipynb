# %%
import pandas as pd

df = pd.read_parquet(r'E:\finsight\data\outputs\loans_scored.parquet')

# Save a sample for Power BI — 100K rows is enough for dashboarding
df.sample(100000, random_state=42).to_csv(
    r'E:\finsight\data\outputs\loans_scored_sample.csv', index=False
)
print("✓ Saved loans_scored_sample.csv")
# Out:
# ✓ Saved loans_scored_sample.csv
